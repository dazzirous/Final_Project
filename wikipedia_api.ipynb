# %%
import requests

def get_wikipedia_categories(title):
    # Define the API endpoint
    url = "https://en.wikipedia.org/w/api.php"
    
    # Define the parameters for the API call
    params = {
        "action": "query",
        "format": "json",
        "titles": title,
        "prop": "categories",
        "cllimit": "max"
         # Retrieve the maximum number of categories
    }
    
    # Make the request to the Wikipedia API
    response = requests.get(url, params=params)
    
    # Parse the JSON response
    data = response.json()
    
    # Extract the page ID (Wikipedia API returns data under page ID)
    pages = data["query"]["pages"]
    page_id = next(iter(pages))  # Get the first (and usually only) page ID
    
    # Check if categories are present
    if "categories" in pages[page_id]:
        categories = pages[page_id]["categories"]
        category_list = [cat["title"] for cat in categories]
        return category_list
    else:
        return None

# Example usage:
title = "Python (programming language)"
categories = get_wikipedia_categories(title)

if categories:
    print(f"Categories for '{title}':")
    for category in categories:
        print(category)
else:
    print(f"No categories found for '{title}'.")
# Out:
# Categories for 'Python (programming language)':
# Category:All articles containing potentially dated statements
# Category:Articles containing potentially dated statements from 2008
# Category:Articles containing potentially dated statements from 2020
# Category:Articles containing potentially dated statements from April 2024
# Category:Articles containing potentially dated statements from December 2022
# Category:Articles containing potentially dated statements from June 2023
# Category:Articles containing potentially dated statements from March 2024
# Category:Articles with BNF identifiers
# Category:Articles with BNFdata identifiers
# Category:Articles with FAST identifiers
# Category:Articles with GND identifiers
# Category:Articles with J9U identifiers
# Category:Articles with LCCN identifiers
# Category:Articles with NKC identifiers
# Category:Articles with SUDOC identifiers
# Category:Articles with example Python (programming language) code
# ...
